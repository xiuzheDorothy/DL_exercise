# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
m = Basemap(projection='mill')
m.drawcoastlines()
plt.show()
# Out:
# E:\anaconda\lib\site-packages\ipykernel_launcher.py:3: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# 我们可以从放大到特定区域来开始：

# %%
m=Basemap(projection='mill',
         llcrnrlat=-40,
         llcrnrlon=-40,
         urcrnrlat = 50,
         urcrnrlon = 75)
m.drawcoastlines()
plt.show()
# Out:
# E:\anaconda\lib\site-packages\ipykernel_launcher.py:5: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   """

# %% [markdown]
# 这里的参数是：
# - llcrnrlat - 左下角的纬度
# - llcrnrlon - 左下角的经度
# - urcrnrlat - 右上角的纬度
# - urcrnrlon - 右上角的经度
#
# 此外，坐标需要转换，其中西经和南纬坐标是负值，北纬和东经坐标是正值。

# %%
plt.figure(figsize=(20,12))
m = Basemap(projection='mill',
llcrnrlat = -90,
llcrnrlon = -180,
urcrnrlat = 90,
urcrnrlon = 180)

m.drawcountries(linewidth=2)# 线宽为2的线画出国家
m.drawstates(color='b')# 蓝色线条画出州
m.drawcounties(color='darkred')
# Out:
# E:\anaconda\lib\site-packages\ipykernel_launcher.py:6: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#
# E:\anaconda\lib\site-packages\ipykernel_launcher.py:8: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#
# E:\anaconda\lib\site-packages\ipykernel_launcher.py:9: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   if __name__ == '__main__':
# E:\anaconda\lib\site-packages\ipykernel_launcher.py:10: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   # Remove the CWD from sys.path while we load stuff.
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-16-ef2eb76ff86d> in <module>
#       8 m.drawcountries(linewidth=2)# 线宽为2的线画出国家
#       9 m.drawstates(color='b')# 蓝色线条画出州
# ---> 10 m.drawcounties(color='darkred')
#
# E:\anaconda\lib\site-packages\mpl_toolkits\basemap\__init__.py in drawcounties(self, linewidth, linestyle, color, antialiased, facecolor, ax, zorder, drawbounds)
#    1987         ax = ax or self._check_ax()
#    1988         county_info = self.readshapefile(gis_file,'counties',\
# -> 1989                       default_encoding='latin-1',drawbounds=drawbounds)
#    1990         counties = [coords for coords in self.counties]
#    1991         counties = PolyCollection(counties)
#
# E:\anaconda\lib\site-packages\mpl_toolkits\basemap\__init__.py in readshapefile(self, shapefile, name, drawbounds, zorder, linewidth, color, antialiased, ax, default_encoding)
#    2154         info = (shf.numRecords,shptype,bbox[0:2]+[0.,0.],bbox[2:]+[0.,0.])
#    2155         npoly = 0
# -> 2156         for shprec in shf.shapeRecords():
#    2157             shp = shprec.shape; rec = shprec.record
#    2158             npoly = npoly + 1
#
# E:\anaconda\lib\site-packages\shapefile.py in shapeRecords(self)
#    1037     def shapeRecords(self):
#    1038         """Returns a list of combination geometry/attribute records for
# -> 1039         all records in a shapefile."""
#    1040         return ShapeRecords([ShapeRecord(shape=rec[0], record=rec[1]) \
#    1041                                 for rec in zip(self.shapes(), self.records())])
#
# E:\anaconda\lib\site-packages\shapefile.py in records(self)
#    1010         records = []
#    1011         f = self.__getFileObj(self.dbf)
# -> 1012         f.seek(self.__dbfHdrLength)
#    1013         for i in range(self.numRecords):
#    1014             r = self.__record(oid=i)
#
# E:\anaconda\lib\site-packages\shapefile.py in __record(self, oid)
#     985                     else:
#     986                         value = None # unknown value is set to missing
# --> 987             else:
#     988                 # anything else is forced to string/unicode
#     989                 value = u(value, self.encoding, self.encodingErrors)
#
# E:\anaconda\lib\site-packages\shapefile.py in u(v, encoding, encodingErrors)
#     102         if isinstance(v, bytes):
#     103             # For python 3 decode bytes to str.
# --> 104             return v.decode(encoding, encodingErrors)
#     105             # return v.decode('latin-1')
#     106         elif isinstance(v, str):
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xf1 in position 2: invalid continuation byte
