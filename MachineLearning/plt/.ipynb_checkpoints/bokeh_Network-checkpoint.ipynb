# %% [markdown]
# # 网络图

# %%
import networkx as nx

from bokeh.io import show, output_notebook
from bokeh.plotting import figure
#from bokeh.models.graphs import from_networkx
from bokeh.models.graphs import from_networkx, NodesAndLinkedEdges, EdgesAndLinkedNodes
from bokeh.models import Plot, Range1d, MultiLine, Circle, HoverTool, TapTool, BoxSelectTool
from bokeh.palettes import Spectral4

output_notebook()
G=nx.karate_club_graph()

plot = figure(title="Networkx Integration Demonstration", x_range=(-1.1,1.1), y_range=(-1.1,1.1),
              tools="pan,wheel_zoom,box_zoom,reset", toolbar_location=None)


#tools = "pan,wheel_zoom,box_zoom,reset"
#graph = from_networkx(G, nx.spring_layout, scale=1, center=(0,0))

graph_renderer = from_networkx(NG, nx.spring_layout, scale=1, center=(0,0))

graph_renderer.node_renderer.glyph = Circle(size=15, fill_color='red',line_color=None)
graph_renderer.node_renderer.selection_glyph = Circle(size=15, fill_color=Spectral4[2])
graph_renderer.node_renderer.hover_glyph = Circle(size=15, fill_color=Spectral4[1])

plot.renderers.append(graph_renderer)

show(plot)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="273c35fb-ef72-4a07-8552-0846ce88b5ba">Loading BokehJS ...</span>
#     </div>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-473efb0eda94> in <module>()
#      26 plot.renderers.append(graph_renderer)
#      27
# ---> 28 show(plot)
#
# E:\anaconda\lib\site-packages\bokeh\io\showing.py in show(obj, browser, new, notebook_handle, notebook_url)
#     135     if obj not in state.document.roots:
#     136         state.document.add_root(obj)
# --> 137     return _show_with_state(obj, state, browser, new, notebook_handle=notebook_handle)
#     138
#     139 #-----------------------------------------------------------------------------
#
# E:\anaconda\lib\site-packages\bokeh\io\showing.py in _show_with_state(obj, state, browser, new, notebook_handle)
#     169
#     170     if state.notebook:
# --> 171         comms_handle = run_notebook_hook(state.notebook_type, 'doc', obj, state, notebook_handle)
#     172         shown = True
#     173
#
# E:\anaconda\lib\site-packages\bokeh\io\notebook.py in run_notebook_hook(notebook_type, action, *args, **kw)
#     286     if _HOOKS[notebook_type][action] is None:
#     287         raise RuntimeError("notebook hook for %r did not install %r action" % notebook_type, action)
# --> 288     return _HOOKS[notebook_type][action](*args, **kw)
#     289
#     290 #-----------------------------------------------------------------------------
#
# E:\anaconda\lib\site-packages\bokeh\io\notebook.py in show_doc(obj, state, notebook_handle)
#     491     from ..embed.notebook import notebook_content
#     492     comms_target = make_id() if notebook_handle else None
# --> 493     (script, div, cell_doc) = notebook_content(obj, comms_target)
#     494
#     495     publish_display_data({HTML_MIME_TYPE: div})
#
# E:\anaconda\lib\site-packages\bokeh\embed\notebook.py in notebook_content(model, notebook_comms_target, theme)
#      80     # has models with the same IDs as they were started with
#      81     with _ModelInEmptyDocument(model, apply_theme=theme) as new_doc:
# ---> 82         (docs_json, render_items) = standalone_docs_json_and_render_items([model])
#      83
#      84     item = render_items[0]
#
# E:\anaconda\lib\site-packages\bokeh\embed\util.py in standalone_docs_json_and_render_items(models)
#     218     docs_json = {}
#     219     for k, v in docs_by_id.items():
# --> 220         docs_json[k] = v.to_json()
#     221
#     222     return (docs_json, render_items)
#
# E:\anaconda\lib\site-packages\bokeh\document\document.py in to_json(self)
#     779         # this is a total hack to go via a string, needed because
#     780         # our BokehJSONEncoder goes straight to a string.
# --> 781         doc_json = self.to_json_string()
#     782         return loads(doc_json)
#     783
#
# E:\anaconda\lib\site-packages\bokeh\document\document.py in to_json_string(self, indent)
#     808         }
#     809
# --> 810         return serialize_json(json, indent=indent)
#     811
#     812     def validate(self):
#
# E:\anaconda\lib\site-packages\bokeh\core\json_encoder.py in serialize_json(obj, pretty, indent, **kwargs)
#     211         indent = 2
#     212
# --> 213     return json.dumps(obj, cls=BokehJSONEncoder, allow_nan=False, indent=indent, separators=separators, sort_keys=True, **kwargs)
#
# E:\anaconda\lib\json\__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     236         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237         separators=separators, default=default, sort_keys=sort_keys,
# --> 238         **kw).encode(obj)
#     239
#     240
#
# E:\anaconda\lib\json\encoder.py in encode(self, o)
#     197         # exceptions aren't as detailed.  The list call should be roughly
#     198         # equivalent to the PySequence_Fast that ''.join() would do.
# --> 199         chunks = self.iterencode(o, _one_shot=True)
#     200         if not isinstance(chunks, (list, tuple)):
#     201             chunks = list(chunks)
#
# E:\anaconda\lib\json\encoder.py in iterencode(self, o, _one_shot)
#     255                 self.key_separator, self.item_separator, self.sort_keys,
#     256                 self.skipkeys, _one_shot)
# --> 257         return _iterencode(o, 0)
#     258
#     259 def _make_iterencode(markers, _default, _encoder, _indent, _floatstr,
#
# TypeError: keys must be a string

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import networkx as nx

plt.figure(figsize=(14,7))
G = nx.generators.directed.random_k_out_graph(10, 3, 0.5)
pos = nx.layout.spring_layout(G)

node_sizes = [3 + 10 * i for i in range(len(G))]
M = G.number_of_edges()
edge_colors = range(2, M + 2)
edge_alphas = [(5 + i) / (M + 4) for i in range(M)]

nodes = nx.draw_networkx_nodes(G, pos, node_size=node_sizes, node_color='blue')
edges = nx.draw_networkx_edges(G, pos, node_size=node_sizes, arrowstyle='|-|',
                               arrowsize=10, edge_color=edge_colors,
                               edge_cmap=plt.cm.Blues, width=2)
# set alpha value for each edge
for i in range(M):
    edges[i].set_alpha(edge_alphas[i])

pc = mpl.collections.PatchCollection(edges, cmap=plt.cm.Blues)
pc.set_array(edge_colors)

plt.colorbar(pc)

ax = plt.gca()
#ax.set_axis_off()
plt.show()

# %%
matplotlib.patches.ArrowStyle
# Out:
# matplotlib.patches.ArrowStyle
